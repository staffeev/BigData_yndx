# %%
with open("store_data.csv", encoding="utf8") as file:
    data = list(map(str.strip, file.readlines()))

# %%
data
# Out:
# ['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil',
#  'burgers,meatballs,eggs',
#  'chutney',
#  'turkey,avocado',
#  'mineral water,milk,energy bar,whole wheat rice,green tea',
#  'low fat yogurt',
#  'whole wheat pasta,french fries',
#  'soup,light cream,shallot',
#  'frozen vegetables,spaghetti,green tea',
#  'french fries',
#  'eggs,pet food',
#  'cookies',
#  'turkey,burgers,mineral water,eggs,cooking oil',
#  'spaghetti,champagne,cookies',
#  'mineral water,salmon',
#  'mineral water',
#  'shrimp,chocolate,chicken,honey,oil,cooking oil,low fat yogurt',
#  'turkey,eggs',
#  'turkey,fresh tuna,tomatoes,spaghetti,mineral water,black tea,salmon,eggs,chicken,extra dark chocolate',
#  'meatballs,milk,honey,french fries,protein bar',
#  'red wine,shrimp,pasta,pepper,eggs,chocolate,shampoo',
# ...

# %%
counts_pairs = {}
counts_ind = {}
for i in data:
    products = i.split(",")
    for j in range(len(products)):
        for z in range(j + 1, len(products)):
            a, b = products[j], products[z]
            counts_ind[a] = counts_ind.get(a, 0) + 1
            counts_ind[b] = counts_ind.get(b, 0) + 1
            counts_pairs[(a, b)] = counts_pairs.get((a, b), 0) + 1
            counts_pairs[(b, a)] = counts_pairs.get((b, a), 0) + 1
for i in counts_pairs:
    counts_pairs[i] /= len(data)

# %%
counts_pairs
# Out:
# {('shrimp', 'almonds'): 0.0022663644847353685,
#  ('almonds', 'shrimp'): 0.0022663644847353685,
#  ('shrimp', 'avocado'): 0.0030662578322890282,
#  ('avocado', 'shrimp'): 0.0030662578322890282,
#  ('shrimp', 'vegetables mix'): 0.0026663111585121984,
#  ('vegetables mix', 'shrimp'): 0.0026663111585121984,
#  ('shrimp', 'green grapes'): 0.0010665244634048793,
#  ('green grapes', 'shrimp'): 0.0010665244634048793,
#  ('shrimp', 'whole weat flour'): 0.0009332089054792694,
#  ('whole weat flour', 'shrimp'): 0.0009332089054792694,
#  ('shrimp', 'yams'): 0.0010665244634048793,
#  ('yams', 'shrimp'): 0.0010665244634048793,
#  ('shrimp', 'cottage cheese'): 0.0026663111585121984,
#  ('cottage cheese', 'shrimp'): 0.0026663111585121984,
#  ('shrimp', 'energy drink'): 0.0027996267164378083,
#  ('energy drink', 'shrimp'): 0.0027996267164378083,
#  ('shrimp', 'tomato juice'): 0.0035995200639914677,
#  ('tomato juice', 'shrimp'): 0.0035995200639914677,
# ...

# %%
c1 = len([i for i in data if "chocolate" in i])
c2 = len([i for i in data if "chocolate" in i and "mineral water" in i])

# %%
c1, c2, c2 / c1
# Out:
# (1346, 448, 0.3328380386329866)

# %%
c2 / c1
# Out:
# 0.3328380386329866

# %%
c1 = len([i for i in data for j in i.strip("\n").split(",") if j == "chocolate"])
c2 = len([i for i in data if "chocolate" in i and "mineral water" in i])

# %%
c1, c2, c2 / c1
# Out:
# (1230, 448, 0.3642276422764228)

# %%
395 / 1230
# Out:
# 0.32113821138211385
